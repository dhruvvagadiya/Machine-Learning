# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('wine_data.csv', header = None).iloc[:, :3]
df.head()
# Out:
#    0      1     2
# 0  1  14.23  1.71
# 1  1  13.20  1.78
# 2  1  13.16  2.36
# 3  1  14.37  1.95
# 4  1  13.24  2.59

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       178 non-null    int64
#  1   1       178 non-null    float64
#  2   2       178 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 4.3 KB

# %%
df.columns = ['Class Label', 'Alcohol', 'Malic Acid']

# %%
df
# Out:
#      Class Label  Alcohol  Malic Acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['Malic Acid'])
# Out:
# <Axes: xlabel='Malic Acid', ylabel='Density'>

# %%
sns.scatterplot(df, x = 'Alcohol', y = 'Malic Acid', hue = 'Class Label')
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic Acid'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class Label', axis = 1), df['Class Label'], test_size = 0.3, random_state = 0)

# %%
X_train.shape
# Out:
# (124, 2)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
## FIT DATA

scaler.fit(X_train)

X_train_trans = scaler.transform(X_train)
X_test_trans = scaler.transform(X_test)

# %%
X_train_trans = pd.DataFrame(X_train_trans, columns = X_train.columns)
X_train_test = pd.DataFrame(X_test_trans, columns = X_train.columns)

# %%
np.round(X_train.describe(), 1)
# Out:
#        Alcohol  Malic Acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.4         1.6
# 50%       13.0         1.9
# 75%       13.6         3.2
# max       14.8         5.6

# %%
np.round(X_train_trans.describe(), 1)
# Out:
#        Alcohol  Malic Acid
# count    124.0       124.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.4         0.2
# 50%        0.5         0.2
# 75%        0.7         0.5
# max        1.0         1.0

# %%
## SEE DATA TRANSFORMED BW 0 TO 1

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize = (12, 5))

ax1.scatter(X_train['Alcohol'], X_train['Malic Acid'], c = y_train)
ax1.set_title('Before')

ax2.scatter(X_train_trans['Alcohol'], X_train_trans['Malic Acid'], c = y_train)
ax2.set_title('After')
# Out:
# Text(0.5, 1.0, 'After')

# %%
## NOW CHECK DISTRBUTION

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize = (12, 5))

ax1.set_title('Before')
sns.kdeplot(X_train['Alcohol'], ax = ax1)
sns.kdeplot(X_train['Malic Acid'], ax = ax1)

ax2.set_title('After')
sns.kdeplot(X_train_trans['Alcohol'], ax = ax2)
sns.kdeplot(X_train_trans['Malic Acid'], ax = ax2)
# Out:
# <Axes: title={'center': 'After'}, xlabel='Alcohol', ylabel='Density'>

# %%
# BASICALLY EVERYTHING COMES DOWN BW 0 -- 1

# %%
# CHECK INDIVIDUAL SCALINGS

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize = (12, 5))

ax1.set_title('Alcohol before')
sns.kdeplot(X_train['Alcohol'], ax = ax1)

ax2.set_title('Alcohol after')
sns.kdeplot(X_train_trans['Alcohol'], ax = ax2)
# Out:
# <Axes: title={'center': 'Alcohol after'}, xlabel='Alcohol', ylabel='Density'>

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize = (12, 5))

ax1.set_title('Malic Acid before')
sns.kdeplot(X_train['Malic Acid'], ax = ax1)

ax2.set_title('Malic Acid after')
sns.kdeplot(X_train_trans['Malic Acid'], ax = ax2)
# Out:
# <Axes: title={'center': 'Malic Acid after'}, xlabel='Malic Acid', ylabel='Density'>

# %%
# SO INDIVIDUAL FEATURES DOESN't GET AFFECTED
